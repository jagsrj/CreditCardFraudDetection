# %% [markdown]
# # Credit Card Fraud Detection - Capstone Project
# ### Student : Jagadish Janakiraman

# %%
# Import Statements
import pandas as pd
from pandasql import sqldf
import pandas as pd
from sklearn import datasets

# %% [markdown]
# ### Task 1 : Load the transaction history data (card_transactions.csv) in a NoSQL database which is MongoDB
# #### (card_transactions.csv will be given to you - you only need to load the data in the MongoDB database)
#
# Data is loaded in Mongo directly

# %% [markdown]
# ### Task 2: Ingest the relevant data (card_member and member_score) from AWS RDS to Hadoop.
#
# This task is done and given to you in form of CSV files named "card_member" and "member_score"}.

# %% [markdown]
# ### Task 3: Create a look-up table in MongoDB {NoSQL database} with columns specified earlier in the problem statement.

# %%
# Load the csv files to pandas dataframe
df_cardMember = pd.read_csv('card_member.csv')
df_member_score = pd.read_csv('member_score.csv')
df_card_transactions = pd.read_csv('card_transactions.csv')

# %%
# check number of records in each dataframe
print("Number of Records in df_cardMember : ", df_cardMember.shape[0])
print("Number of Records in df_member_score is :", df_member_score.shape[0])
print("Number of Records in df_card_transactions is :", df_card_transactions.shape[0])
# Out:
# Number of Records in df_cardMember :  999
# Number of Records in df_member_score is : 999
# Number of Records in df_card_transactions is : 53292

# %%
df_cardMember
# Out:
#               card_id        member_id      member_joining_dt  \
# 0     340028465709212    9250698176266  2012-02-08 06:04:13.0
# 1     340054675199675  835873341185231  2017-03-10 09:24:44.0
# 2     340082915339645  512969555857346  2014-02-15 06:30:30.0
# 3     340134186926007  887711945571282  2012-02-05 01:21:58.0
# 4     340265728490548  680324265406190  2014-03-29 07:49:14.0
# ..                ...              ...                    ...
# 994  6595814135833988  236864426408837  2011-02-18 06:45:46.0
# 995  6595928469079750  422173403853722  2012-02-10 02:19:20.0
# 996  6597703848279563  657991752750272  2017-02-16 07:45:34.0
# 997  6598830758632447  660350842993890  2013-07-26 02:22:17.0
# 998  6599900931314251  928036864799687  2017-09-09 03:31:54.0
#
#     card_purchase_dt        country              city
# 0              05/13  United States         Barberton
# 1              03/17  United States        Fort Dodge
# 2              07/14  United States            Graham
# 3              02/13  United States         Dix Hills
# 4              11/14  United States  Rancho Cucamonga
# ..               ...            ...               ...
# 994            06/14  United States          Johnston
# 995            02/14  United States           Raleigh
# 996            03/17  United States          Pinewood
# 997            12/16  United States             Tampa
# 998            10/17  United States        Loves Park
#
# [999 rows x 6 columns]

# %%
df_member_score
# Out:
#            member_id  score
# 0        37495066290    339
# 1       117826301530    289
# 2      1147922084344    393
# 3      1314074991813    225
# 4      1739553947511    642
# ..               ...    ...
# 994  992104321998571    658
# 995  992552823055811    694
# 996  994983851226493    687
# 997  996411635289270    335
# 998  997128952368160    683
#
# [999 rows x 2 columns]

# %%
# take only genuine transactions into the dataframe
df_card_transactions = df_card_transactions[df_card_transactions.status == 'GENUINE']
df_card_transactions
# Out:
#                 card_id        member_id   amount  postcode           pos_id  \
# 0       348702330256514      37495066290  9084849     33946  614677375609919
# 1       348702330256514      37495066290   330148     33946  614677375609919
# 2       348702330256514      37495066290   136052     33946  614677375609919
# 3       348702330256514      37495066290  4310362     33946  614677375609919
# 4       348702330256514      37495066290  9097094     33946  614677375609919
# ...                 ...              ...      ...       ...              ...
# 53287  5391723993945313  997128952368160  7234353     54514  366418882890893
# 53288  5391723993945313  997128952368160   283051     20711  479856487174409
# 53289  5391723993945313  997128952368160  5527334     20711  479856487174409
# 53290  5391723993945313  997128952368160   714092     20711  479856487174409
# 53291  5391723993945313  997128952368160  2053925     99929  283991209995468
#
#             transaction_dt   status
# 0      11-02-2018 00:00:00  GENUINE
# 1      11-02-2018 00:00:00  GENUINE
# 2      11-02-2018 00:00:00  GENUINE
# 3      11-02-2018 00:00:00  GENUINE
# 4      11-02-2018 00:00:00  GENUINE
# ...                    ...      ...
# 53287  30-01-2018 14:21:15  GENUINE
# 53288  30-11-2017 05:24:26  GENUINE
# 53289  30-11-2017 07:09:46  GENUINE
# 53290  30-11-2017 12:25:47  GENUINE
# 53291  31-12-2017 23:20:13  GENUINE
#
# [53210 rows x 7 columns]

# %%
df_card_transactions.dtypes
# Out:
# card_id            int64
# member_id          int64
# amount             int64
# postcode           int64
# pos_id             int64
# transaction_dt    object
# status            object
# dtype: object

# %%
#convert from object to datetime
df_card_transactions['transaction_dt2']=pd.to_datetime(df_card_transactions['transaction_dt'])

# %%
df_card_transactions.dtypes
# Out:
# card_id                     int64
# member_id                   int64
# amount                      int64
# postcode                    int64
# pos_id                      int64
# transaction_dt             object
# status                     object
# transaction_dt2    datetime64[ns]
# dtype: object

# %%
# Sort descending order
df_card_transactions.sort_values(by=['member_id','transaction_dt2'], inplace=True,
               ascending = [True, False])
df_card_transactions
# Out:
#                 card_id        member_id   amount  postcode           pos_id  \
# 0       348702330256514      37495066290  9084849     33946  614677375609919
# 1       348702330256514      37495066290   330148     33946  614677375609919
# 2       348702330256514      37495066290   136052     33946  614677375609919
# 3       348702330256514      37495066290  4310362     33946  614677375609919
# 4       348702330256514      37495066290  9097094     33946  614677375609919
# ...                 ...              ...      ...       ...              ...
# 53207  5391723993945313  997128952368160  1396526     53968  716276786938354
# 53206  5391723993945313  997128952368160    25146     13124  200432834928149
# 53205  5391723993945313  997128952368160  2727621     57376   97278983752405
# 53204  5391723993945313  997128952368160  7201018     48832  712082643297946
# 53201  5391723993945313  997128952368160  6790715     68790  957396750250096
#
#             transaction_dt   status     transaction_dt2
# 0      11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00
# 1      11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00
# 2      11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00
# 3      11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00
# 4      11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00
# ...                    ...      ...                 ...
# 53207  05-11-2017 12:00:54  GENUINE 2017-05-11 12:00:54
# 53206  04-11-2017 18:27:33  GENUINE 2017-04-11 18:27:33
# 53205  03-12-2017 22:56:34  GENUINE 2017-03-12 22:56:34
# 53204  03-11-2017 19:38:11  GENUINE 2017-03-11 19:38:11
# 53201  02-11-2017 20:48:49  GENUINE 2017-02-11 20:48:49
#
# [53210 rows x 8 columns]

# %%
#Group by card_id, date in descending order and create a rank column
# keep only top 10 rank for UCL calcuation
df_card_transactions["Rank"] = df_card_transactions.groupby("card_id")["transaction_dt2"].rank(ascending=False, method='dense').astype(int)
df_card_transactions.sort_values("Rank")
df_card_transactions_top10 = df_card_transactions[(df_card_transactions.Rank <=10) ]
df_card_transactions_top10
# Out:
#                 card_id        member_id   amount  postcode           pos_id  \
# 0       348702330256514      37495066290  9084849     33946  614677375609919
# 1       348702330256514      37495066290   330148     33946  614677375609919
# 2       348702330256514      37495066290   136052     33946  614677375609919
# 3       348702330256514      37495066290  4310362     33946  614677375609919
# 4       348702330256514      37495066290  9097094     33946  614677375609919
# ...                 ...              ...      ...       ...              ...
# 53202  5391723993945313  997128952368160  9670623     77974  675701087475560
# 53200  5391723993945313  997128952368160  1164872     93210  171173202259233
# 53287  5391723993945313  997128952368160  7234353     54514  366418882890893
# 53284  5391723993945313  997128952368160  2683995     44065   42771743906415
# 53283  5391723993945313  997128952368160  1036903     44065   42771743906415
#
#             transaction_dt   status     transaction_dt2  Rank
# 0      11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# 1      11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# 2      11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# 3      11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# 4      11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# ...                    ...      ...                 ...   ...
# 53202  03-01-2018 07:30:58  GENUINE 2018-03-01 07:30:58     6
# 53200  02-01-2018 19:13:37  GENUINE 2018-02-01 19:13:37     7
# 53287  30-01-2018 14:21:15  GENUINE 2018-01-30 14:21:15     8
# 53284  29-01-2018 13:46:33  GENUINE 2018-01-29 13:46:33     9
# 53283  29-01-2018 12:01:13  GENUINE 2018-01-29 12:01:13    10
#
# [10953 rows x 9 columns]

# %%
#Check if only genuine transactions exist
df_card_transactions_top10.groupby('status')['status'].value_counts()
# Out:
# status   status
# GENUINE  GENUINE    10953
# Name: status, dtype: int64

# %%
# calculate mean and standard deviation on amount for each member
df_ucl_sd = df_card_transactions_top10.groupby(['member_id'])['amount'].agg(['mean', 'std'])
df_ucl_sd
# Out:
#                          mean           std
# member_id
# 37495066290      4.260123e+06  2.917135e+06
# 117826301530     4.300037e+06  2.666817e+06
# 1147922084344    3.442887e+06  2.816608e+06
# 1314074991813    4.937506e+06  2.618911e+06
# 1739553947511    5.040048e+06  3.333798e+06
# ...                       ...           ...
# 992104321998571  6.906752e+06  2.194694e+06
# 992552823055811  4.959108e+06  3.389936e+06
# 994983851226493  5.433286e+06  2.733345e+06
# 996411635289270  5.629739e+06  3.168106e+06
# 997128952368160  5.094256e+06  3.053936e+06
#
# [999 rows x 2 columns]

# %%
# reset index to make member_id a column
df_ucl_sd = df_ucl_sd.reset_index()
df_ucl_sd
# Out:
#            member_id          mean           std
# 0        37495066290  4.260123e+06  2.917135e+06
# 1       117826301530  4.300037e+06  2.666817e+06
# 2      1147922084344  3.442887e+06  2.816608e+06
# 3      1314074991813  4.937506e+06  2.618911e+06
# 4      1739553947511  5.040048e+06  3.333798e+06
# ..               ...           ...           ...
# 994  992104321998571  6.906752e+06  2.194694e+06
# 995  992552823055811  4.959108e+06  3.389936e+06
# 996  994983851226493  5.433286e+06  2.733345e+06
# 997  996411635289270  5.629739e+06  3.168106e+06
# 998  997128952368160  5.094256e+06  3.053936e+06
#
# [999 rows x 3 columns]

# %%
# check datatypes on the dataframe
df_ucl_sd.dtypes
# Out:
# member_id      int64
# mean         float64
# std          float64
# dtype: object

# %%
# rename columns
df_ucl_sd.rename(columns = {'mean':'Avg1', 'std':'SD'}, inplace = True)

# %%
# calculate UCL with below formula
df_ucl_sd['ucl'] = df_ucl_sd.Avg1 +  3*df_ucl_sd.SD

# %%
df_ucl_sd
# Out:
#            member_id          Avg1            SD           ucl
# 0        37495066290  4.260123e+06  2.917135e+06  1.301153e+07
# 1       117826301530  4.300037e+06  2.666817e+06  1.230049e+07
# 2      1147922084344  3.442887e+06  2.816608e+06  1.189271e+07
# 3      1314074991813  4.937506e+06  2.618911e+06  1.279424e+07
# 4      1739553947511  5.040048e+06  3.333798e+06  1.504144e+07
# ..               ...           ...           ...           ...
# 994  992104321998571  6.906752e+06  2.194694e+06  1.349084e+07
# 995  992552823055811  4.959108e+06  3.389936e+06  1.512892e+07
# 996  994983851226493  5.433286e+06  2.733345e+06  1.363332e+07
# 997  996411635289270  5.629739e+06  3.168106e+06  1.513406e+07
# 998  997128952368160  5.094256e+06  3.053936e+06  1.425606e+07
#
# [999 rows x 4 columns]

# %%
# keep only rank 1 for furthe processing 
lstTxnPostCodeTxDate = df_card_transactions[df_card_transactions.Rank ==1]
lstTxnPostCodeTxDate
# Out:
#                 card_id        member_id   amount  postcode           pos_id  \
# 0       348702330256514      37495066290  9084849     33946  614677375609919
# 1       348702330256514      37495066290   330148     33946  614677375609919
# 2       348702330256514      37495066290   136052     33946  614677375609919
# 3       348702330256514      37495066290  4310362     33946  614677375609919
# 4       348702330256514      37495066290  9097094     33946  614677375609919
# ...                 ...              ...      ...       ...              ...
# 53046  5115273575078211  992104321998571  8416500     42082  609717185246135
# 53097   374878208630443  992552823055811  4185444     12747  640304888744272
# 53162  5399715069800093  994983851226493  4302555     77432  487096286569669
# 53189  4981548424137027  996411635289270  4993560     92694  181718433544561
# 53213  5391723993945313  997128952368160  7338503     42323  662287296546616
#
#             transaction_dt   status     transaction_dt2  Rank
# 0      11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# 1      11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# 2      11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# 3      11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# 4      11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# ...                    ...      ...                 ...   ...
# 53046  08-01-2018 15:40:29  GENUINE 2018-08-01 15:40:29     1
# 53097  04-01-2018 22:08:21  GENUINE 2018-04-01 22:08:21     1
# 53162  30-01-2018 09:05:15  GENUINE 2018-01-30 09:05:15     1
# 53189  18-12-2017 00:01:04  GENUINE 2017-12-18 00:01:04     1
# 53213  08-01-2018 12:09:49  GENUINE 2018-08-01 12:09:49     1
#
# [1658 rows x 9 columns]

# %%
# merge dataframes to get other columns - transaction date, postcode, ucl
tmp1 = df_ucl_sd.merge(lstTxnPostCodeTxDate, on='member_id', how='left')
tmp1
# Out:
#             member_id          Avg1            SD           ucl  \
# 0         37495066290  4.260123e+06  2.917135e+06  1.301153e+07
# 1         37495066290  4.260123e+06  2.917135e+06  1.301153e+07
# 2         37495066290  4.260123e+06  2.917135e+06  1.301153e+07
# 3         37495066290  4.260123e+06  2.917135e+06  1.301153e+07
# 4         37495066290  4.260123e+06  2.917135e+06  1.301153e+07
# ...               ...           ...           ...           ...
# 1653  992104321998571  6.906752e+06  2.194694e+06  1.349084e+07
# 1654  992552823055811  4.959108e+06  3.389936e+06  1.512892e+07
# 1655  994983851226493  5.433286e+06  2.733345e+06  1.363332e+07
# 1656  996411635289270  5.629739e+06  3.168106e+06  1.513406e+07
# 1657  997128952368160  5.094256e+06  3.053936e+06  1.425606e+07
#
#                card_id   amount  postcode           pos_id  \
# 0      348702330256514  9084849     33946  614677375609919
# 1      348702330256514   330148     33946  614677375609919
# 2      348702330256514   136052     33946  614677375609919
# 3      348702330256514  4310362     33946  614677375609919
# 4      348702330256514  9097094     33946  614677375609919
# ...                ...      ...       ...              ...
# 1653  5115273575078211  8416500     42082  609717185246135
# 1654   374878208630443  4185444     12747  640304888744272
# 1655  5399715069800093  4302555     77432  487096286569669
# 1656  4981548424137027  4993560     92694  181718433544561
# 1657  5391723993945313  7338503     42323  662287296546616
#
#            transaction_dt   status     transaction_dt2  Rank
# 0     11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# 1     11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# 2     11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# 3     11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# 4     11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# ...                   ...      ...                 ...   ...
# 1653  08-01-2018 15:40:29  GENUINE 2018-08-01 15:40:29     1
# 1654  04-01-2018 22:08:21  GENUINE 2018-04-01 22:08:21     1
# 1655  30-01-2018 09:05:15  GENUINE 2018-01-30 09:05:15     1
# 1656  18-12-2017 00:01:04  GENUINE 2017-12-18 00:01:04     1
# 1657  08-01-2018 12:09:49  GENUINE 2018-08-01 12:09:49     1
#
# [1658 rows x 12 columns]

# %%
# merge dataframe to get score
tmp2 = df_member_score.merge(tmp1, on='member_id', how='left')
tmp2
# Out:
#             member_id  score          Avg1            SD           ucl  \
# 0         37495066290    339  4.260123e+06  2.917135e+06  1.301153e+07
# 1         37495066290    339  4.260123e+06  2.917135e+06  1.301153e+07
# 2         37495066290    339  4.260123e+06  2.917135e+06  1.301153e+07
# 3         37495066290    339  4.260123e+06  2.917135e+06  1.301153e+07
# 4         37495066290    339  4.260123e+06  2.917135e+06  1.301153e+07
# ...               ...    ...           ...           ...           ...
# 1653  992104321998571    658  6.906752e+06  2.194694e+06  1.349084e+07
# 1654  992552823055811    694  4.959108e+06  3.389936e+06  1.512892e+07
# 1655  994983851226493    687  5.433286e+06  2.733345e+06  1.363332e+07
# 1656  996411635289270    335  5.629739e+06  3.168106e+06  1.513406e+07
# 1657  997128952368160    683  5.094256e+06  3.053936e+06  1.425606e+07
#
#                card_id   amount  postcode           pos_id  \
# 0      348702330256514  9084849     33946  614677375609919
# 1      348702330256514   330148     33946  614677375609919
# 2      348702330256514   136052     33946  614677375609919
# 3      348702330256514  4310362     33946  614677375609919
# 4      348702330256514  9097094     33946  614677375609919
# ...                ...      ...       ...              ...
# 1653  5115273575078211  8416500     42082  609717185246135
# 1654   374878208630443  4185444     12747  640304888744272
# 1655  5399715069800093  4302555     77432  487096286569669
# 1656  4981548424137027  4993560     92694  181718433544561
# 1657  5391723993945313  7338503     42323  662287296546616
#
#            transaction_dt   status     transaction_dt2  Rank
# 0     11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# 1     11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# 2     11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# 3     11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# 4     11-02-2018 00:00:00  GENUINE 2018-11-02 00:00:00     1
# ...                   ...      ...                 ...   ...
# 1653  08-01-2018 15:40:29  GENUINE 2018-08-01 15:40:29     1
# 1654  04-01-2018 22:08:21  GENUINE 2018-04-01 22:08:21     1
# 1655  30-01-2018 09:05:15  GENUINE 2018-01-30 09:05:15     1
# 1656  18-12-2017 00:01:04  GENUINE 2017-12-18 00:01:04     1
# 1657  08-01-2018 12:09:49  GENUINE 2018-08-01 12:09:49     1
#
# [1658 rows x 13 columns]

# %%
# drop the redundant columns
columns = ['amount', 'pos_id', 'status', 'transaction_dt', 'status', 'Rank', 'Avg1', 'SD']
tmp2.drop(columns, inplace=True, axis=1)
lookup_df = tmp2
lookup_df = lookup_df.drop_duplicates(subset=['member_id'])
lookup_df = lookup_df.reset_index()
lookup_df
# Out:
#      index        member_id  score           ucl           card_id  postcode  \
# 0        0      37495066290    339  1.301153e+07   348702330256514     33946
# 1       42     117826301530    289  1.230049e+07  5189563368503974     30234
# 2       43    1147922084344    393  1.189271e+07  5407073344486464     63770
# 3       44    1314074991813    225  1.279424e+07   378303738095292     41778
# 4       45    1739553947511    642  1.504144e+07   348413196172048     92258
# ..     ...              ...    ...           ...               ...       ...
# 994   1653  992104321998571    658  1.349084e+07  5115273575078211     42082
# 995   1654  992552823055811    694  1.512892e+07   374878208630443     12747
# 996   1655  994983851226493    687  1.363332e+07  5399715069800093     77432
# 997   1656  996411635289270    335  1.513406e+07  4981548424137027     92694
# 998   1657  997128952368160    683  1.425606e+07  5391723993945313     42323
#
#         transaction_dt2
# 0   2018-11-02 00:00:00
# 1   2018-06-01 09:15:04
# 2   2018-01-18 10:55:30
# 3   2018-06-01 14:31:05
# 4   2018-12-01 21:29:58
# ..                  ...
# 994 2018-08-01 15:40:29
# 995 2018-04-01 22:08:21
# 996 2018-01-30 09:05:15
# 997 2017-12-18 00:01:04
# 998 2018-08-01 12:09:49
#
# [999 rows x 7 columns]

# %%
#final lookup dataframe
final_lookup_df = lookup_df[['member_id','score','ucl','card_id','postcode','transaction_dt2']]
final_lookup_df
# Out:
#            member_id  score           ucl           card_id  postcode  \
# 0        37495066290    339  1.301153e+07   348702330256514     33946
# 1       117826301530    289  1.230049e+07  5189563368503974     30234
# 2      1147922084344    393  1.189271e+07  5407073344486464     63770
# 3      1314074991813    225  1.279424e+07   378303738095292     41778
# 4      1739553947511    642  1.504144e+07   348413196172048     92258
# ..               ...    ...           ...               ...       ...
# 994  992104321998571    658  1.349084e+07  5115273575078211     42082
# 995  992552823055811    694  1.512892e+07   374878208630443     12747
# 996  994983851226493    687  1.363332e+07  5399715069800093     77432
# 997  996411635289270    335  1.513406e+07  4981548424137027     92694
# 998  997128952368160    683  1.425606e+07  5391723993945313     42323
#
#         transaction_dt2
# 0   2018-11-02 00:00:00
# 1   2018-06-01 09:15:04
# 2   2018-01-18 10:55:30
# 3   2018-06-01 14:31:05
# 4   2018-12-01 21:29:58
# ..                  ...
# 994 2018-08-01 15:40:29
# 995 2018-04-01 22:08:21
# 996 2018-01-30 09:05:15
# 997 2017-12-18 00:01:04
# 998 2018-08-01 12:09:49
#
# [999 rows x 6 columns]

# %%
#saving the file to csv ; this file is loaded into mongodb
#determining the name of the file
file_name = 'lookupTable4.csv'

#saving the excel
final_lookup_df.to_csv(file_name) 
print('DataFrame lookup_df - is written to Excel File successfully.')
# Out:
# DataFrame lookup_df - is written to Excel File successfully.
